# %% [markdown]
# # Plots for the results of different parameters alpha and gamma and the comparison between optimizer

# %%
# Imports
import pandas as pd
import ast
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Testing different alpha and gamma values

# %%
# Load the data
file_path = "data/alpha_gamma_results.csv"
data = pd.read_csv(file_path)

# Correct the pivot syntax
heatmap_data = data.pivot(index="alpha_init", columns="gamma_init", values="final_test_accuracy")

# Create the heatmap again with corrected data preparation
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="viridis", cbar_kws={'label': 'Final Test Accuracy'})
plt.title("Final Test Accuracy depending on Alpha and Gamma (before edit)")
plt.xlabel("Gamma Init")
plt.ylabel("Alpha Init")
plt.show()


# Load the data
file_path = "data/alpha_gamma_results-new.csv"
data = pd.read_csv(file_path)

# Correct the pivot syntax
heatmap_data = data.pivot(index="alpha_init", columns="gamma_init", values="final_test_accuracy")

# Create the heatmap again with corrected data preparation
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="viridis", cbar_kws={'label': 'Final Test Accuracy'})
plt.title("Final Test Accuracy depending on Alpha and Gamma")
plt.xlabel("Gamma Init")
plt.ylabel("Alpha Init")
plt.show()

# %%
# Load the data
file_path = "data/alpha_gamma_results.csv"
data = pd.read_csv(file_path)

# Correct the pivot syntax
heatmap_data = data.pivot(index="alpha_init", columns="gamma_init", values="avg_test_accuracy")

# Create the heatmap again with corrected data preparation
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="viridis", cbar_kws={'label': 'Avg Test Accuracy'})
plt.title("Avg Test Accuracy depending on Alpha and Gamma (before edit)")
plt.xlabel("Gamma Init")
plt.ylabel("Alpha Init")
plt.show()



# Load the data
file_path = "data/alpha_gamma_results-new.csv"
data = pd.read_csv(file_path)

# Correct the pivot syntax
heatmap_data = data.pivot(index="alpha_init", columns="gamma_init", values="avg_test_accuracy")

# Create the heatmap again with corrected data preparation
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="viridis", cbar_kws={'label': 'Avg Test Accuracy'})
plt.title("Average Test Accuracy depending on Alpha and Gamma")
plt.xlabel("Gamma Init")
plt.ylabel("Alpha Init")
plt.show()

# %%
# Load the data
file_path = "data/alpha_gamma_results.csv"
data = pd.read_csv(file_path)

# Correct the pivot syntax
heatmap_data = data.pivot(index="alpha_init", columns="gamma_init", values="avg_losses")

# Create the heatmap again with corrected data preparation
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="viridis", cbar_kws={'label': 'Avg Losses'})
plt.title("Avg Losses depending on Alpha and Gamma (before edit)")
plt.xlabel("Gamma Init")
plt.ylabel("Alpha Init")
plt.show()


# Load the data
file_path = "data/alpha_gamma_results-new.csv"
data = pd.read_csv(file_path)

# Correct the pivot syntax
heatmap_data = data.pivot(index="alpha_init", columns="gamma_init", values="avg_losses")

# Create the heatmap again with corrected data preparation
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="viridis", cbar_kws={'label': 'Avg Losses'})
plt.title("Average Losses depending on Alpha and Gamma")
plt.xlabel("Gamma Init")
plt.ylabel("Alpha Init")
plt.show()

# %%
# Load the data
file_path = "data/alpha_gamma_results.csv"
data = pd.read_csv(file_path)

# Correct the pivot syntax
heatmap_data = data.pivot(index="alpha_init", columns="gamma_init", values="final_losses")

# Create the heatmap again with corrected data preparation
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="viridis", cbar_kws={'label': 'Final Losses'})
plt.title("Final Losses depending on Alpha and Gamma (before edit)")
plt.xlabel("Gamma Init")
plt.ylabel("Alpha Init")
plt.show()

# Load the data
file_path = "data/alpha_gamma_results-new.csv"
data = pd.read_csv(file_path)

# Correct the pivot syntax
heatmap_data = data.pivot(index="alpha_init", columns="gamma_init", values="final_losses")

# Create the heatmap again with corrected data preparation
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="viridis", cbar_kws={'label': 'Final Losses'})
plt.title("Final Losses depending on Alpha and Gamma")
plt.xlabel("Gamma Init")
plt.ylabel("Alpha Init")
plt.show()

# %% [markdown]
# # Differences between ensemble sizes

# %%
# Load the CSV file
file_path = 'data/ensemble_size_results.csv'
df = pd.read_csv(file_path)

# Extract the relevant columns: ensemble_size, lr, and avg_test_accuracy
df_subset = df[['ensemble_size', 'lr', 'avg_test_accuracy']]

# Create the plot
plt.figure(figsize=(10, 6))

# Create a plot for each learning rate
for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['avg_test_accuracy'], label=f'LR={lr_value}')

# Label the axes and add a title
plt.xlabel('Ensemble Size')
plt.ylabel('Average Test Accuracy')
plt.title('Average Test Accuracy vs. Ensemble Size for Different Learning Rates (before edit)')
plt.legend(title='Learning Rate')
plt.show()

# Load the CSV file
file_path = 'data/ensemble_size_results-new.csv'
df = pd.read_csv(file_path)

# Extract the relevant columns: ensemble_size, lr, and avg_test_accuracy
df_subset = df[['ensemble_size', 'lr', 'avg_test_accuracy']]

# Create the plot
plt.figure(figsize=(10, 6))

# Create a plot for each learning rate
for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['avg_test_accuracy'], label=f'LR={lr_value}')

# Label the axes and add a title
plt.xlabel('Ensemble Size')
plt.ylabel('Average Test Accuracy')
plt.title('Average Test Accuracy depending on Ensemble Size')
plt.legend(title='Learning Rate')
plt.show()

# %%
# Load the CSV file
file_path = 'data/ensemble_size_results.csv'
df = pd.read_csv(file_path)

df_subset = df[['ensemble_size', 'lr', 'avg_losses']]

# Create the plot
plt.figure(figsize=(10, 6))

# Create a plot for each learning rate
for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['avg_losses'], label=f'LR={lr_value}')

# Label the axes and add a title
plt.xlabel('Ensemble Size')
plt.ylabel('Average Losses')
plt.title('Average Losses vs. Ensemble Size for Different Learning Rates (before edit)')
plt.legend(title='Learning Rate')
plt.show()


# Load the CSV file
file_path = 'data/ensemble_size_results-new.csv'
df = pd.read_csv(file_path)

df_subset = df[['ensemble_size', 'lr', 'avg_losses']]

# Create the plot
plt.figure(figsize=(10, 6))

# Create a plot for each learning rate
for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['avg_losses'], label=f'LR={lr_value}')

# Label the axes and add a title
plt.xlabel('Ensemble Size')
plt.ylabel('Average Losses')
plt.title('Average Losses depending on Ensemble Size')
plt.legend(title='Learning Rate')
plt.show()

# %%
# Load the CSV file
file_path = 'data/ensemble_size_results.csv'
df = pd.read_csv(file_path)

# Extract the relevant columns: ensemble_size, lr, and avg_test_accuracy
df_subset = df[['ensemble_size', 'lr', 'final_test_accuracy']]

# Create the plot
plt.figure(figsize=(10, 6))

# Create a plot for each learning rate
for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['final_test_accuracy'], label=f'LR={lr_value}')

# Label the axes and add a title
plt.xlabel('Ensemble Size')
plt.ylabel('Final Test Accuracy')
plt.title('Final Test Accuracy vs. Ensemble Size for Different Learning Rates (before edit)')
plt.legend(title='Learning Rate')
plt.show()



# Load the CSV file
file_path = 'data/ensemble_size_results-new.csv'
df = pd.read_csv(file_path)

# Extract the relevant columns: ensemble_size, lr, and avg_test_accuracy
df_subset = df[['ensemble_size', 'lr', 'final_test_accuracy']]

# Create the plot
plt.figure(figsize=(10, 6))

# Create a plot for each learning rate
for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['final_test_accuracy'], label=f'LR={lr_value}')

# Label the axes and add a title
plt.xlabel('Ensemble Size')
plt.ylabel('Final Test Accuracy')
plt.title('Final Test Accuracy depending on Ensemble Size')
plt.legend(title='Learning Rate')
plt.show()

# %%
# Load the CSV file
file_path = 'data/ensemble_size_results.csv'
df = pd.read_csv(file_path)

df_subset = df[['ensemble_size', 'lr', 'final_losses']]

# Create the plot
plt.figure(figsize=(10, 6))

# Create a plot for each learning rate
for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['final_losses'], label=f'LR={lr_value}')

# Label the axes and add a title
plt.xlabel('Ensemble Size')
plt.ylabel('Final Losses')
plt.title('Final Losses vs. Ensemble Size for Different Learning Rates (before edit)')
plt.legend(title='Learning Rate')
plt.show()

# Pivot the data to create a heatmap-friendly format
heatmap_data = df.pivot_table(values='final_test_accuracy', 
                              index='ensemble_size', 
                              columns='lr')

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt='.2f', cbar_kws={'label': 'Final Test Accuracy'})
plt.title('Heatmap of Final Test Accuracy by Ensemble Size and Learning Rate (before edit)')
plt.xlabel('Learning Rate')
plt.ylabel('Ensemble Size')
plt.show()


# Load the CSV file
file_path = 'data/ensemble_size_results-new.csv'
df = pd.read_csv(file_path)

df_subset = df[['ensemble_size', 'lr', 'final_losses']]

# Create the plot
plt.figure(figsize=(10, 6))

# Create a plot for each learning rate
for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['final_losses'], label=f'LR={lr_value}')

# Label the axes and add a title
plt.xlabel('Ensemble Size')
plt.ylabel('Final Losses')
plt.title('Final Losses depending on Ensemble Size')
plt.legend(title='Learning Rate')
plt.show()

# Pivot the data to create a heatmap-friendly format
heatmap_data = df.pivot_table(values='final_test_accuracy', 
                              index='ensemble_size', 
                              columns='lr')

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt='.2f', cbar_kws={'label': 'Final Test Accuracy'})
plt.title('Heatmap of Final Test Accuracy by Ensemble Size and Learning Rate (after edit)')
plt.xlabel('Learning Rate')
plt.ylabel('Ensemble Size')
plt.show()

# %%
# Load the CSV file
file_path = 'data/ensemble_size_results-new.csv'
df = pd.read_csv(file_path)

# Extract the relevant columns: ensemble_size, lr, and avg_test_accuracy
df_subset = df[['ensemble_size', 'lr', 'final_test_accuracy']]

# Create the plot
plt.figure(figsize=(10, 6))

# Create a plot for each learning rate
for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['final_test_accuracy'], label=f'LR={lr_value}')

# Label the axes and add a title
plt.xlabel('Ensemble Size')
plt.ylabel('Final Test Accuracy')
plt.title('Final Test Accuracy depending on Ensemble Size')
plt.legend(title='Learning Rate')
plt.show()


# Load the CSV file
file_path = 'data/ensemble_size_results-new.csv'
df = pd.read_csv(file_path)

# Extract the relevant columns: ensemble_size, lr, and avg_test_accuracy
df_subset = df[['ensemble_size', 'lr', 'avg_test_accuracy']]

# Create the plot
plt.figure(figsize=(10, 6))

# Create a plot for each learning rate
for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['avg_test_accuracy'], label=f'LR={lr_value}')

# Label the axes and add a title
plt.xlabel('Ensemble Size')
plt.ylabel('Average Test Accuracy')
plt.title('Average Test Accuracy depending on Ensemble Size')
plt.legend(title='Learning Rate')
plt.show()

# %%
# Load the CSV file
file_path = 'data/ensemble_size_results-new.csv'
df = pd.read_csv(file_path)

# Extract the relevant columns
df_subset = df[['ensemble_size', 'lr', 'final_test_accuracy', 'avg_test_accuracy']]

# Create the plot for both final and average test accuracy
plt.figure(figsize=(12, 8))

for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['final_test_accuracy'], label=f'Final Accuracy (LR={lr_value})', linestyle='-')
    plt.plot(subset['ensemble_size'], subset['avg_test_accuracy'], label=f'Avg Accuracy (LR={lr_value})', linestyle='--')

plt.xlabel('Ensemble Size')
plt.ylabel('Accuracy')
plt.title('Final and Average Test Accuracy depending on Ensemble Size')
plt.legend(title='Learning Rate')
plt.show()

# %%
# Load the CSV file
file_path = 'data/ensemble_size_results-new.csv'
df = pd.read_csv(file_path)

df_subset = df[['ensemble_size', 'lr', 'avg_losses']]

# Create the plot
plt.figure(figsize=(10, 6))

# Create a plot for each learning rate
for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['avg_losses'], label=f'LR={lr_value}')

# Label the axes and add a title
plt.xlabel('Ensemble Size')
plt.ylabel('Average Losses')
plt.title('Average Losses depending on Ensemble Size')
plt.legend(title='Learning Rate')
plt.show()

# Load the CSV file
file_path = 'data/ensemble_size_results-new.csv'
df = pd.read_csv(file_path)

df_subset = df[['ensemble_size', 'lr', 'final_losses']]

# Create the plot
plt.figure(figsize=(10, 6))

# Create a plot for each learning rate
for lr_value in df_subset['lr'].unique():
    subset = df_subset[df_subset['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['final_losses'], label=f'LR={lr_value}')

# Label the axes and add a title
plt.xlabel('Ensemble Size')
plt.ylabel('Final Losses')
plt.title('Final Losses depending on Ensemble Size')
plt.legend(title='Learning Rate')
plt.show()

# %%
# Load the CSV file
file_path = 'data/ensemble_size_results-new.csv'
df = pd.read_csv(file_path)

# Extract the relevant columns for losses
df_subset_loss = df[['ensemble_size', 'lr', 'avg_losses', 'final_losses']]

# Create the plot for both final and average losses
plt.figure(figsize=(12, 8))

for lr_value in df_subset_loss['lr'].unique():
    subset = df_subset_loss[df_subset_loss['lr'] == lr_value]
    plt.plot(subset['ensemble_size'], subset['avg_losses'], label=f'Avg Losses (LR={lr_value})', linestyle='--')
    plt.plot(subset['ensemble_size'], subset['final_losses'], label=f'Final Losses (LR={lr_value})', linestyle='-')

plt.xlabel('Ensemble Size')
plt.ylabel('Losses')
plt.title('Final and Average Losses depending on Ensemble Size')
plt.legend(title='Learning Rate')
plt.show()

# %% [markdown]
# # Optimizer Comparison Plots

# %%
# Load and preprocess data from multiple files
file_paths = ["data/adam_results_simple_complex.csv", "data/adam_results_8_batchensemble.csv", "data/sgd_results_simple_complex.csv", "data/sgd_results_8_batchensemble.csv", "data/ivon_results_simple_complex.csv", "data/ivon_results_8_batchensemble.csv"]
optimizers = ["Adam", "Adam", "SGD", "SGD", "IVON", "IVON"]

# Load and preprocess the data
datasets = []
for path in file_paths:
    data = pd.read_csv(path)
    for column in ['train_loss', 'val_loss', 'train_acc', 'val_acc']:
        data[column] = data[column].apply(ast.literal_eval)
    datasets.append(data)

# Plot Train Loss
plt.figure(figsize=(10, 6))
for data, optimizer in zip(datasets, optimizers):
    subset1 = data[data['model_type'] == "complex"]
    subset2 = data[data['model_type'] == "batchensemble_complex"]

    for _, row in subset1.iterrows():
        epochs = range(1, len(row['train_loss']) + 1)
        plt.plot(epochs, row['train_loss'], label=f"{optimizer} - complex")
    for _, row in subset2.iterrows():
        epochs = range(1, len(row['train_loss']) + 1)
        plt.plot(epochs, row['train_loss'], label=f"{optimizer} - batchensemble_complex")

plt.title("Optimizer Comparison for Single Network and BatchEnsemble - Train Loss", fontsize=14)
plt.xlabel("Epochs", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.legend(fontsize=12, loc='best')
plt.tight_layout()
plt.show()

# Plot Validation Loss
plt.figure(figsize=(10, 6))
for data, optimizer in zip(datasets, optimizers):
    subset1 = data[data['model_type'] == "complex"]
    subset2 = data[data['model_type'] == "batchensemble_complex"]

    for _, row in subset1.iterrows():
        epochs = range(1, len(row['val_loss']) + 1)
        plt.plot(epochs, row['val_loss'], label=f"{optimizer} - complex")
    for _, row in subset2.iterrows():
        epochs = range(1, len(row['val_loss']) + 1)
        plt.plot(epochs, row['val_loss'], label=f"{optimizer} - batchensemble_complex")

plt.title("Optimizer Comparison for Single Network and BatchEnsemble - Validation Loss", fontsize=14)
plt.xlabel("Epochs", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.legend(fontsize=12, loc='best')
plt.tight_layout()
plt.show()

# Plot Train Accuracy
plt.figure(figsize=(10, 6))
for data, optimizer in zip(datasets, optimizers):
    subset1 = data[data['model_type'] == "complex"]
    subset2 = data[data['model_type'] == "batchensemble_complex"]

    for _, row in subset1.iterrows():
        epochs = range(1, len(row['train_acc']) + 1)
        plt.plot(epochs, row['train_acc'], label=f"{optimizer} - complex")
    for _, row in subset2.iterrows():
        epochs = range(1, len(row['train_acc']) + 1)
        plt.plot(epochs, row['train_acc'], label=f"{optimizer} - batchensemble_complex")

plt.title("Optimizer Comparison for Single Network and BatchEnsemble - Train Accuracy", fontsize=14)
plt.xlabel("Epochs", fontsize=12)
plt.ylabel("Accuracy (%)", fontsize=12)
plt.legend(fontsize=12, loc='best')
plt.tight_layout()
plt.show()

# Plot Validation Accuracy
plt.figure(figsize=(10, 6))
for data, optimizer in zip(datasets, optimizers):
    subset1 = data[data['model_type'] == "complex"]
    subset2 = data[data['model_type'] == "batchensemble_complex"]

    for _, row in subset1.iterrows():
        epochs = range(1, len(row['val_acc']) + 1)
        plt.plot(epochs, row['val_acc'], label=f"{optimizer} - complex")
    for _, row in subset2.iterrows():
        epochs = range(1, len(row['val_acc']) + 1)
        plt.plot(epochs, row['val_acc'], label=f"{optimizer} - batchensemble_complex")
        
plt.title("Optimizer Comparison for Single Network and BatchEnsemble - Validation Accuracy", fontsize=14)
plt.xlabel("Epochs", fontsize=12)
plt.ylabel("Accuracy (%)", fontsize=12)
plt.legend(fontsize=12, loc='best')
plt.tight_layout()
plt.show()
