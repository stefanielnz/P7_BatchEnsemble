# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm  # For progress bars

# Set random seed for reproducibility
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

# Hyperparameters (You can adjust these)
num_epochs = 10           # Number of training epochs
batch_size = 128         # Batch size for training and validation
learning_rate = 0.0001    # Learning rate for optimizer
weight_decay = 1e-4      # Weight decay (L2 regularization)
validation_split = 0.1   # Fraction of training data to use for validation

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Data preprocessing and loading
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],  # CIFAR-10 mean
        std=[0.2023, 0.1994, 0.2010]    # CIFAR-10 std
    ),
])

# Load the full training dataset
full_train_dataset = datasets.CIFAR10(root='./data', train=True,
                                      download=True, transform=transform)

# Split into training and validation datasets
train_size = int((1 - validation_split) * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(full_train_dataset, [train_size, val_size])

# Test dataset
test_dataset = datasets.CIFAR10(root='./data', train=False,
                                download=True, transform=transform)

# Data loaders
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                         batch_size=batch_size,
                                         shuffle=False)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)

# VGG11 with Parameter Sharing Within the Network
class VGG11SharedWeights(nn.Module):
    def __init__(self, num_classes=10, share_weights='none'):
        super(VGG11SharedWeights, self).__init__()
        self.share_weights = share_weights

        # Shared convolutional layers
        self.shared_conv_64 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.shared_conv_256 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.shared_conv_512 = nn.Conv2d(512, 512, kernel_size=3, padding=1)

        # Build features
        self.features = self._make_layers()

        # Classifier
        self.classifier = nn.Linear(512, num_classes)

    def _make_layers(self):
        layers = []

        # Conv1
        if self.share_weights in ['all', 'early']:
            layers += [
                nn.Conv2d(3, 64, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                self.shared_conv_64,
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2, stride=2)
            ]
        else:
            layers += [
                nn.Conv2d(3, 64, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.Conv2d(64, 64, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2, stride=2)
            ]

        # Conv2
        layers += [
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        ]

        # Conv3
        layers += [
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        ]

        # Conv4
        if self.share_weights in ['all', 'deep']:
            layers += [
                self.shared_conv_256,
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2, stride=2)
            ]
        else:
            layers += [
                nn.Conv2d(256, 256, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2, stride=2)
            ]

        # Conv5
        layers += [
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        ]

        # Conv6
        if self.share_weights in ['all', 'deep']:
            layers += [
                self.shared_conv_512,
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2, stride=2)
            ]
        else:
            layers += [
                nn.Conv2d(512, 512, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2, stride=2)
            ]

        # Conv7
        if self.share_weights in ['all', 'deep']:
            layers += [
                self.shared_conv_512,
                nn.ReLU(inplace=True)
            ]
        else:
            layers += [
                nn.Conv2d(512, 512, kernel_size=3, padding=1),
                nn.ReLU(inplace=True)
            ]

        # Conv8
        if self.share_weights in ['all', 'deep']:
            layers += [
                self.shared_conv_512,
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2, stride=2)
            ]
        else:
            layers += [
                nn.Conv2d(512, 512, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2, stride=2)
            ]

        return nn.Sequential(*layers)

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# Corrected function to count parameters for intra-model sharing
def count_parameters_intra(model):
    total_params = sum(p.numel() for p in model.parameters())

    # Collect parameter IDs from shared layers that are actually used
    shared_param_ids = set()
    if model.share_weights in ['all', 'early']:
        shared_param_ids.update([id(p) for p in model.shared_conv_64.parameters()])
    if model.share_weights in ['all', 'deep']:
        shared_param_ids.update([id(p) for p in model.shared_conv_256.parameters()])
        shared_param_ids.update([id(p) for p in model.shared_conv_512.parameters()])

    # Calculate shared and unique parameters
    num_shared_params = sum(p.numel() for p in model.parameters() if id(p) in shared_param_ids)
    num_unique_params = total_params - num_shared_params

    return num_unique_params, num_shared_params
    
# Training function with validation and progress bars
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        # Training loop with progress bar
        with tqdm(total=len(train_loader), desc=f'Epoch {epoch+1}/{num_epochs}', unit='batch') as pbar:
            for images, labels in train_loader:
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass
                outputs = model(images)
                loss = criterion(outputs, labels)

                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                running_loss += loss.item()

                # Calculate accuracy
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                pbar.update(1)

        epoch_loss = running_loss / len(train_loader)
        epoch_accuracy = 100 * correct / total
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_accuracy)

        # Validation loop
        model.eval()
        val_running_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                val_running_loss += loss.item()

                # Calculate accuracy
                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        val_loss = val_running_loss / len(val_loader)
        val_accuracy = 100 * val_correct / val_total
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)

        print(f'Epoch [{epoch+1}/{num_epochs}], '
              f'Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_accuracy:.2f}%, '
              f'Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%')

    return train_losses, val_losses, train_accuracies, val_accuracies

# Evaluation function on test set
def evaluate_model(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in tqdm(test_loader, desc='Testing', unit='batch'):
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    test_accuracy = 100 * correct / total
    return test_accuracy

# Plotting function with training and validation metrics
def plot_results(train_losses_list, val_losses_list, train_acc_list, val_acc_list, labels):
    num_models = len(train_losses_list)
    fig, axs = plt.subplots(2, num_models, figsize=(6 * num_models, 10))

    if num_models == 1:
        axs = [axs]

    for i in range(num_models):
        # Loss plot
        axs[0, i].plot(train_losses_list[i], label='Train Loss')
        axs[0, i].plot(val_losses_list[i], label='Val Loss')
        axs[0, i].set_xlabel('Epoch')
        axs[0, i].set_ylabel('Loss')
        axs[0, i].set_title(f'{labels[i]} Loss')
        axs[0, i].legend()

        # Accuracy plot
        axs[1, i].plot(train_acc_list[i], label='Train Acc')
        axs[1, i].plot(val_acc_list[i], label='Val Acc')
        axs[1, i].set_xlabel('Epoch')
        axs[1, i].set_ylabel('Accuracy (%)')
        axs[1, i].set_title(f'{labels[i]} Accuracy')
        axs[1, i].legend()

    plt.tight_layout()
    plt.show()

# Parameter distribution plotting function
@torch.no_grad()
def plot_parameter_distribution(model, model_label="Model"):
    params = []
    tags = []
    for name, param in model.named_parameters():
        params.append(param.cpu().flatten())
        tags += [name] * param.numel()
    params = torch.cat(params).numpy()
    tags = np.array(tags)
    df = pd.DataFrame({'Parameter Value': params, 'Parameter Name': tags})

    plt.figure(figsize=(8, 6))
    sns.kdeplot(data=df, x='Parameter Value', fill=True)
    plt.title(f'Parameter Distribution of {model_label}')
    plt.xlabel('Parameter Value')
    plt.ylabel('Density')
    plt.show()

# Main function to train and evaluate models with different sharing options
def main():
    sharing_options = ['none', 'early', 'deep', 'all']
    train_losses_list = []
    val_losses_list = []
    train_acc_list = []
    val_acc_list = []
    test_accuracies_list = []
    labels = []

    for sharing_option in sharing_options:
        print(f"\nTraining model with sharing option: {sharing_option}")
        model = VGG11SharedWeights(share_weights=sharing_option).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

        # Count parameters
        num_unique_params, num_shared_params = count_parameters_intra(model)
        total_params = num_unique_params + num_shared_params
        print(f"Total parameters: {total_params}")
        print(f"Unique parameters: {num_unique_params}")
        print(f"Shared parameters: {num_shared_params}")

        train_losses, val_losses, train_accuracies, val_accuracies = train_model(
            model, train_loader, val_loader, criterion, optimizer, num_epochs)
        test_accuracy = evaluate_model(model, test_loader)
        print(f'Test Accuracy on CIFAR-10 test set: {test_accuracy:.2f}%')

        train_losses_list.append(train_losses)
        val_losses_list.append(val_losses)
        train_acc_list.append(train_accuracies)
        val_acc_list.append(val_accuracies)
        test_accuracies_list.append(test_accuracy)
        labels.append(f'Sharing: {sharing_option}')

        # Plot parameter distribution
        plot_parameter_distribution(model, model_label=f'Sharing: {sharing_option}')

    # Plot training results
    plot_results(train_losses_list, val_losses_list, train_acc_list, val_acc_list, labels)

    # Print test accuracies
    for i, sharing_option in enumerate(sharing_options):
        print(f'Test Accuracy for sharing option {sharing_option}: {test_accuracies_list[i]:.2f}%')

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Files already downloaded and verified
# Files already downloaded and verified
#
# Training model with sharing option: none
# Total parameters: 12249354
# Unique parameters: 12249354
# Shared parameters: 0
# Epoch 1/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:25<00:00, 13.82batch/s]
# Epoch [1/10], Train Loss: 1.8020, Train Acc: 31.83%, Val Loss: 1.5578, Val Acc: 41.48%
# Epoch 2/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:28<00:00, 12.36batch/s]
# Epoch [2/10], Train Loss: 1.4627, Train Acc: 45.18%, Val Loss: 1.3621, Val Acc: 49.32%
# Epoch 3/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:31<00:00, 11.34batch/s]
# Epoch [3/10], Train Loss: 1.2790, Train Acc: 52.94%, Val Loss: 1.1970, Val Acc: 55.56%
# Epoch 4/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:31<00:00, 11.30batch/s]
# Epoch [4/10], Train Loss: 1.1382, Train Acc: 58.59%, Val Loss: 1.1168, Val Acc: 58.32%
# Epoch 5/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:31<00:00, 11.34batch/s]
# Epoch [5/10], Train Loss: 1.0198, Train Acc: 63.04%, Val Loss: 0.9818, Val Acc: 64.34%
# Epoch 6/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 14.96batch/s]
# Epoch [6/10], Train Loss: 0.9233, Train Acc: 66.79%, Val Loss: 0.9499, Val Acc: 64.82%
# Epoch 7/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:37<00:00,  9.30batch/s]
# Epoch [7/10], Train Loss: 0.8316, Train Acc: 70.13%, Val Loss: 0.8330, Val Acc: 69.56%
# Epoch 8/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:33<00:00, 10.52batch/s]
# Epoch [8/10], Train Loss: 0.7399, Train Acc: 73.78%, Val Loss: 0.7975, Val Acc: 70.54%
# Epoch 9/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:31<00:00, 11.14batch/s]
# Epoch [9/10], Train Loss: 0.6471, Train Acc: 77.08%, Val Loss: 0.7342, Val Acc: 73.68%
# Epoch 10/10: 100%|████████████████████████████████████████████████████████████████| 352/352 [00:35<00:00, 10.04batch/s]
# Epoch [10/10], Train Loss: 0.5803, Train Acc: 79.70%, Val Loss: 0.7189, Val Acc: 74.16%
# Testing: 100%|██████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 31.66batch/s]
# Test Accuracy on CIFAR-10 test set: 73.39%
# Training model with sharing option: early
# Total parameters: 12212426
# Unique parameters: 12175498
# Shared parameters: 36928
# Epoch 1/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:32<00:00, 10.73batch/s]
# Epoch [1/10], Train Loss: 1.8156, Train Acc: 30.81%, Val Loss: 1.5737, Val Acc: 40.14%
# Epoch 2/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:31<00:00, 11.07batch/s]
# Epoch [2/10], Train Loss: 1.4643, Train Acc: 45.01%, Val Loss: 1.3560, Val Acc: 50.20%
# Epoch 3/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:34<00:00, 10.34batch/s]
# Epoch [3/10], Train Loss: 1.2637, Train Acc: 53.07%, Val Loss: 1.2044, Val Acc: 56.44%
# Epoch 4/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:32<00:00, 10.94batch/s]
# Epoch [4/10], Train Loss: 1.1097, Train Acc: 59.46%, Val Loss: 1.0753, Val Acc: 60.34%
# Epoch 5/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:31<00:00, 11.22batch/s]
# Epoch [5/10], Train Loss: 0.9902, Train Acc: 63.84%, Val Loss: 0.9360, Val Acc: 65.36%
# Epoch 6/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:31<00:00, 11.20batch/s]
# Epoch [6/10], Train Loss: 0.8910, Train Acc: 67.69%, Val Loss: 0.9197, Val Acc: 66.70%
# Epoch 7/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:29<00:00, 12.08batch/s]
# Epoch [7/10], Train Loss: 0.7861, Train Acc: 71.61%, Val Loss: 0.8012, Val Acc: 71.20%
# Epoch 8/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:27<00:00, 12.71batch/s]
# Epoch [8/10], Train Loss: 0.7068, Train Acc: 74.64%, Val Loss: 0.7517, Val Acc: 72.16%
# Epoch 9/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:27<00:00, 12.72batch/s]
# Epoch [9/10], Train Loss: 0.6281, Train Acc: 77.43%, Val Loss: 0.7200, Val Acc: 73.90%
# Epoch 10/10: 100%|████████████████████████████████████████████████████████████████| 352/352 [00:30<00:00, 11.40batch/s]
# Epoch [10/10], Train Loss: 0.5518, Train Acc: 80.32%, Val Loss: 0.7527, Val Acc: 73.70%
# Testing: 100%|██████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 27.73batch/s]
# Test Accuracy on CIFAR-10 test set: 72.63%
# Training model with sharing option: deep
# Total parameters: 4579850
# Unique parameters: 1629962
# Shared parameters: 2949888
# Epoch 1/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:28<00:00, 12.16batch/s]
# Epoch [1/10], Train Loss: 1.8652, Train Acc: 28.58%, Val Loss: 1.5877, Val Acc: 39.14%
# Epoch 2/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:27<00:00, 12.94batch/s]
# Epoch [2/10], Train Loss: 1.4798, Train Acc: 44.60%, Val Loss: 1.3900, Val Acc: 49.38%
# Epoch 3/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:28<00:00, 12.38batch/s]
# Epoch [3/10], Train Loss: 1.2984, Train Acc: 51.96%, Val Loss: 1.2426, Val Acc: 54.60%
# Epoch 4/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:28<00:00, 12.15batch/s]
# Epoch [4/10], Train Loss: 1.1529, Train Acc: 57.94%, Val Loss: 1.1123, Val Acc: 59.78%
# Epoch 5/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:27<00:00, 12.87batch/s]
# Epoch [5/10], Train Loss: 1.0449, Train Acc: 62.12%, Val Loss: 1.0154, Val Acc: 62.84%
# Epoch 6/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:27<00:00, 12.90batch/s]
# Epoch [6/10], Train Loss: 0.9550, Train Acc: 65.24%, Val Loss: 0.9674, Val Acc: 64.92%
# Epoch 7/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:29<00:00, 12.12batch/s]
# Epoch [7/10], Train Loss: 0.8751, Train Acc: 68.20%, Val Loss: 0.9084, Val Acc: 67.60%
# Epoch 8/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:28<00:00, 12.44batch/s]
# Epoch [8/10], Train Loss: 0.7956, Train Acc: 71.21%, Val Loss: 0.8593, Val Acc: 68.06%
# Epoch 9/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.11batch/s]
# Epoch [9/10], Train Loss: 0.7252, Train Acc: 74.05%, Val Loss: 0.7603, Val Acc: 72.04%
# Epoch 10/10: 100%|████████████████████████████████████████████████████████████████| 352/352 [00:06<00:00, 51.12batch/s]
# Epoch [10/10], Train Loss: 0.6436, Train Acc: 77.15%, Val Loss: 0.7309, Val Acc: 73.14%
# Testing: 100%|██████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 76.42batch/s]
# Test Accuracy on CIFAR-10 test set: 73.83%
# Training model with sharing option: all
# Total parameters: 4542922
# Unique parameters: 1556106
# Shared parameters: 2986816
# Epoch 1/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:06<00:00, 50.58batch/s]
# Epoch [1/10], Train Loss: 1.8635, Train Acc: 28.88%, Val Loss: 1.6263, Val Acc: 38.96%
# Epoch 2/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.58batch/s]
# Epoch [2/10], Train Loss: 1.5104, Train Acc: 43.57%, Val Loss: 1.4039, Val Acc: 48.50%
# Epoch 3/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:06<00:00, 50.49batch/s]
# Epoch [3/10], Train Loss: 1.3120, Train Acc: 51.41%, Val Loss: 1.2331, Val Acc: 54.46%
# Epoch 4/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.89batch/s]
# Epoch [4/10], Train Loss: 1.1509, Train Acc: 57.90%, Val Loss: 1.1227, Val Acc: 58.38%
# Epoch 5/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.47batch/s]
# Epoch [5/10], Train Loss: 1.0499, Train Acc: 61.75%, Val Loss: 1.0554, Val Acc: 61.24%
# Epoch 6/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 48.28batch/s]
# Epoch [6/10], Train Loss: 0.9505, Train Acc: 65.55%, Val Loss: 0.9389, Val Acc: 66.00%
# Epoch 7/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 50.27batch/s]
# Epoch [7/10], Train Loss: 0.8660, Train Acc: 68.80%, Val Loss: 0.8615, Val Acc: 67.68%
# Epoch 8/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:06<00:00, 50.37batch/s]
# Epoch [8/10], Train Loss: 0.7854, Train Acc: 71.88%, Val Loss: 0.8206, Val Acc: 70.24%
# Epoch 9/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:06<00:00, 50.56batch/s]
# Epoch [9/10], Train Loss: 0.7169, Train Acc: 74.45%, Val Loss: 0.7517, Val Acc: 72.40%
# Epoch 10/10: 100%|████████████████████████████████████████████████████████████████| 352/352 [00:06<00:00, 50.36batch/s]
# Epoch [10/10], Train Loss: 0.6476, Train Acc: 77.04%, Val Loss: 0.7313, Val Acc: 73.82%
# Testing: 100%|██████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 74.72batch/s]
# Test Accuracy on CIFAR-10 test set: 73.28%
# Test Accuracy for sharing option none: 73.39%
# Test Accuracy for sharing option early: 72.63%
# Test Accuracy for sharing option deep: 73.83%
# Test Accuracy for sharing option all: 73.28%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm  # For progress bars

# Set random seed for reproducibility
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

# Hyperparameters (You can adjust these)
num_epochs = 10           # Number of training epochs
batch_size = 128         # Batch size for training and validation
learning_rate = 0.0001    # Learning rate for optimizer
weight_decay = 1e-4      # Weight decay (L2 regularization)
validation_split = 0.1   # Fraction of training data to use for validation
num_heads = 8            # Number of ensemble members (heads)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Data preprocessing and loading
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],  # CIFAR-10 mean
        std=[0.2023, 0.1994, 0.2010]    # CIFAR-10 std
    ),
])

# Load the full training dataset
full_train_dataset = datasets.CIFAR10(root='./data', train=True,
                                      download=True, transform=transform)

# Split into training and validation datasets
train_size = int((1 - validation_split) * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(full_train_dataset, [train_size, val_size])

# Test dataset
test_dataset = datasets.CIFAR10(root='./data', train=False,
                                download=True, transform=transform)

# Data loaders
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                         batch_size=batch_size,
                                         shuffle=False)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)

# VGG11 with Parameter Sharing Between Ensemble Members
class VGG11ParameterSharing(nn.Module):
    def __init__(self, num_classes=10, num_heads=4, sharing_option='no_sharing'):
        super(VGG11ParameterSharing, self).__init__()
        self.num_heads = num_heads
        self.sharing_option = sharing_option

        # Define shared layers
        self.shared_layers = nn.Sequential()
        self.heads = nn.ModuleList()

        # Define the layers of VGG11
        layers = [
            # Conv1
            ('conv1', nn.Conv2d(3, 64, kernel_size=3, padding=1)),
            ('relu1', nn.ReLU(inplace=True)),
            ('pool1', nn.MaxPool2d(kernel_size=2, stride=2)),

            # Conv2
            ('conv2', nn.Conv2d(64, 128, kernel_size=3, padding=1)),
            ('relu2', nn.ReLU(inplace=True)),
            ('pool2', nn.MaxPool2d(kernel_size=2, stride=2)),

            # Conv3
            ('conv3', nn.Conv2d(128, 256, kernel_size=3, padding=1)),
            ('relu3', nn.ReLU(inplace=True)),

            # Conv4
            ('conv4', nn.Conv2d(256, 256, kernel_size=3, padding=1)),
            ('relu4', nn.ReLU(inplace=True)),
            ('pool3', nn.MaxPool2d(kernel_size=2, stride=2)),

            # Conv5
            ('conv5', nn.Conv2d(256, 512, kernel_size=3, padding=1)),
            ('relu5', nn.ReLU(inplace=True)),

            # Conv6
            ('conv6', nn.Conv2d(512, 512, kernel_size=3, padding=1)),
            ('relu6', nn.ReLU(inplace=True)),
            ('pool4', nn.MaxPool2d(kernel_size=2, stride=2)),

            # Conv7
            ('conv7', nn.Conv2d(512, 512, kernel_size=3, padding=1)),
            ('relu7', nn.ReLU(inplace=True)),

            # Conv8
            ('conv8', nn.Conv2d(512, 512, kernel_size=3, padding=1)),
            ('relu8', nn.ReLU(inplace=True)),
            ('pool5', nn.MaxPool2d(kernel_size=2, stride=2)),
        ]

        # Determine which layers to share based on the sharing_option
        if self.sharing_option == 'no_sharing':
            shared_indices = []
        elif self.sharing_option == 'early':
            shared_indices = list(range(6))  # Up to 'pool2'
        elif self.sharing_option == 'deep':
            shared_indices = list(range(6, len(layers)))  # From 'conv3' onwards
        elif self.sharing_option == 'all':
            shared_indices = list(range(len(layers)))  # All layers
        else:
            raise ValueError("Invalid sharing_option. Choose from 'no_sharing', 'early', 'deep', 'all'.")

        # Build shared layers
        for idx in shared_indices:
            name, layer = layers[idx]
            self.shared_layers.add_module(name, layer)

        # Build per-head layers
        for _ in range(num_heads):
            head_layers = nn.Sequential()
            for idx, (name, layer) in enumerate(layers):
                if idx not in shared_indices:
                    head_layers.add_module(name, layer)
            # Add classifier
            head_layers.add_module('flatten', nn.Flatten())
            head_layers.add_module('classifier', nn.Linear(512, num_classes))
            self.heads.append(head_layers)

        # If all layers are shared, add classifier to shared layers
        if self.sharing_option == 'all':
            self.shared_layers.add_module('flatten', nn.Flatten())
            self.shared_layers.add_module('classifier', nn.Linear(512, num_classes))

    def forward(self, x):
        outputs = []
        if self.sharing_option == 'deep':
            # For deep sharing, per-head layers are applied first
            per_head_outputs = []
            for head in self.heads:
                # Apply per-head layers up to 'pool2' (first 6 layers)
                out = head[:6](x.clone())
                per_head_outputs.append(out)
            # Apply shared layers
            shared_outs = []
            for out in per_head_outputs:
                shared_out = self.shared_layers(out)
                shared_outs.append(shared_out)
            # Apply per-head classifier layers
            for idx, out in enumerate(shared_outs):
                # The classifier is the last two layers in the per-head layers
                classifier = self.heads[idx][-2:]  # 'flatten' and 'classifier'
                out = classifier(out)
                outputs.append(out)
        else:
            if len(self.shared_layers) > 0:
                x = self.shared_layers(x)
            for head in self.heads:
                if self.sharing_option == 'all':
                    out = x
                else:
                    out = head(x.clone())
                outputs.append(out)
        outputs = torch.stack(outputs)  # Shape: [num_heads, batch_size, num_classes]
        x = outputs.mean(dim=0)  # Average over ensemble members
        return x

# Corrected function to count parameters for inter-model sharing
def count_parameters_inter(model):
    total_params = sum(p.numel() for p in model.parameters())
    shared_param_ids = set()
    if len(model.shared_layers) > 0:
        shared_param_ids.update([id(p) for p in model.shared_layers.parameters()])
    num_shared_params = sum(p.numel() for p in model.parameters() if id(p) in shared_param_ids)
    num_unique_params = total_params - num_shared_params
    return num_unique_params, num_shared_params

# Training function with validation and progress bars
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        # Training loop with progress bar
        with tqdm(total=len(train_loader), desc=f'Epoch {epoch+1}/{num_epochs}', unit='batch') as pbar:
            for images, labels in train_loader:
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass
                outputs = model(images)
                loss = criterion(outputs, labels)

                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                running_loss += loss.item()

                # Calculate accuracy
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                pbar.update(1)

        epoch_loss = running_loss / len(train_loader)
        epoch_accuracy = 100 * correct / total
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_accuracy)

        # Validation loop
        model.eval()
        val_running_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                val_running_loss += loss.item()

                # Calculate accuracy
                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        val_loss = val_running_loss / len(val_loader)
        val_accuracy = 100 * val_correct / val_total
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)

        print(f'Epoch [{epoch+1}/{num_epochs}], '
              f'Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_accuracy:.2f}%, '
              f'Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%')

    return train_losses, val_losses, train_accuracies, val_accuracies

# Evaluation function on test set
def evaluate_model(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in tqdm(test_loader, desc='Testing', unit='batch'):
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    test_accuracy = 100 * correct / total
    return test_accuracy

# Plotting function with training and validation metrics
def plot_results(train_losses_list, val_losses_list, train_acc_list, val_acc_list, labels):
    num_models = len(train_losses_list)
    fig, axs = plt.subplots(2, num_models, figsize=(6 * num_models, 10))

    if num_models == 1:
        axs = [axs]

    for i in range(num_models):
        # Loss plot
        axs[0, i].plot(train_losses_list[i], label='Train Loss')
        axs[0, i].plot(val_losses_list[i], label='Val Loss')
        axs[0, i].set_xlabel('Epoch')
        axs[0, i].set_ylabel('Loss')
        axs[0, i].set_title(f'{labels[i]} Loss')
        axs[0, i].legend()

        # Accuracy plot
        axs[1, i].plot(train_acc_list[i], label='Train Acc')
        axs[1, i].plot(val_acc_list[i], label='Val Acc')
        axs[1, i].set_xlabel('Epoch')
        axs[1, i].set_ylabel('Accuracy (%)')
        axs[1, i].set_title(f'{labels[i]} Accuracy')
        axs[1, i].legend()

    plt.tight_layout()
    plt.show()

# Parameter distribution plotting function
@torch.no_grad()
def plot_parameter_distribution(model, model_label="Model"):
    params = []
    tags = []
    for name, param in model.named_parameters():
        params.append(param.cpu().flatten())
        tags += [name] * param.numel()
    params = torch.cat(params).numpy()
    tags = np.array(tags)
    df = pd.DataFrame({'Parameter Value': params, 'Parameter Name': tags})

    plt.figure(figsize=(8, 6))
    sns.kdeplot(data=df, x='Parameter Value', fill=True)
    plt.title(f'Parameter Distribution of {model_label}')
    plt.xlabel('Parameter Value')
    plt.ylabel('Density')
    plt.show()

# Main function to train and evaluate models with different sharing options
def main():
    sharing_options = ['no_sharing', 'early', 'deep', 'all']
    train_losses_list = []
    val_losses_list = []
    train_acc_list = []
    val_acc_list = []
    test_accuracies_list = []
    labels = []

    for sharing_option in sharing_options:
        print(f"\nTraining model with sharing option: {sharing_option}")
        model = VGG11ParameterSharing(num_heads=num_heads, sharing_option=sharing_option).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

        # Count parameters
        num_unique_params, num_shared_params = count_parameters_inter(model)
        total_params = num_unique_params + num_shared_params
        print(f"Total parameters: {total_params}")
        print(f"Unique parameters: {num_unique_params}")
        print(f"Shared parameters: {num_shared_params}")

        train_losses, val_losses, train_accuracies, val_accuracies = train_model(
            model, train_loader, val_loader, criterion, optimizer, num_epochs)
        test_accuracy = evaluate_model(model, test_loader)
        print(f'Test Accuracy on CIFAR-10 test set: {test_accuracy:.2f}%')

        train_losses_list.append(train_losses)
        val_losses_list.append(val_losses)
        train_acc_list.append(train_accuracies)
        val_acc_list.append(val_accuracies)
        test_accuracies_list.append(test_accuracy)
        labels.append(f'Sharing: {sharing_option}')

        # Plot parameter distribution
        plot_parameter_distribution(model, model_label=f'Sharing: {sharing_option}')

    # Plot training results
    plot_results(train_losses_list, val_losses_list, train_acc_list, val_acc_list, labels)

    # Print test accuracies
    for i, sharing_option in enumerate(sharing_options):
        print(f'Test Accuracy for sharing option {sharing_option}: {test_accuracies_list[i]:.2f}%')

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Files already downloaded and verified
# Files already downloaded and verified
#
# Training model with sharing option: no_sharing
# Total parameters: 9261520
# Unique parameters: 9261520
# Shared parameters: 0
# Epoch 1/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:20<00:00, 17.45batch/s]
# Epoch [1/10], Train Loss: 1.8365, Train Acc: 30.31%, Val Loss: 1.6367, Val Acc: 38.34%
# Epoch 2/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.79batch/s]
# Epoch [2/10], Train Loss: 1.4755, Train Acc: 44.56%, Val Loss: 1.3694, Val Acc: 49.60%
# Epoch 3/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.80batch/s]
# Epoch [3/10], Train Loss: 1.2714, Train Acc: 53.26%, Val Loss: 1.2568, Val Acc: 54.14%
# Epoch 4/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.76batch/s]
# Epoch [4/10], Train Loss: 1.1325, Train Acc: 58.37%, Val Loss: 1.0756, Val Acc: 60.46%
# Epoch 5/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.77batch/s]
# Epoch [5/10], Train Loss: 1.0234, Train Acc: 62.93%, Val Loss: 1.0218, Val Acc: 62.94%
# Epoch 6/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.68batch/s]
# Epoch [6/10], Train Loss: 0.9324, Train Acc: 66.46%, Val Loss: 0.9992, Val Acc: 63.90%
# Epoch 7/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.76batch/s]
# Epoch [7/10], Train Loss: 0.8313, Train Acc: 70.16%, Val Loss: 0.8887, Val Acc: 67.60%
# Epoch 8/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.69batch/s]
# Epoch [8/10], Train Loss: 0.7422, Train Acc: 73.32%, Val Loss: 0.8574, Val Acc: 69.16%
# Epoch 9/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.76batch/s]
# Epoch [9/10], Train Loss: 0.6629, Train Acc: 76.39%, Val Loss: 0.8035, Val Acc: 70.88%
# Epoch 10/10: 100%|████████████████████████████████████████████████████████████████| 352/352 [00:20<00:00, 17.48batch/s]
# Epoch [10/10], Train Loss: 0.5688, Train Acc: 79.74%, Val Loss: 0.7937, Val Acc: 71.78%
# Testing: 100%|██████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 42.60batch/s]
# Test Accuracy on CIFAR-10 test set: 72.08%
# Training model with sharing option: early
# Total parameters: 9261520
# Unique parameters: 9185872
# Shared parameters: 75648
# Epoch 1/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:16<00:00, 20.84batch/s]
# Epoch [1/10], Train Loss: 1.8668, Train Acc: 28.37%, Val Loss: 1.6021, Val Acc: 37.98%
# Epoch 2/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:16<00:00, 21.00batch/s]
# Epoch [2/10], Train Loss: 1.4991, Train Acc: 42.97%, Val Loss: 1.3891, Val Acc: 48.68%
# Epoch 3/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:16<00:00, 21.01batch/s]
# Epoch [3/10], Train Loss: 1.3124, Train Acc: 51.08%, Val Loss: 1.2346, Val Acc: 55.30%
# Epoch 4/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:16<00:00, 20.99batch/s]
# Epoch [4/10], Train Loss: 1.1584, Train Acc: 57.57%, Val Loss: 1.0867, Val Acc: 60.20%
# Epoch 5/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:16<00:00, 21.00batch/s]
# Epoch [5/10], Train Loss: 1.0433, Train Acc: 61.95%, Val Loss: 1.0481, Val Acc: 61.52%
# Epoch 6/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:16<00:00, 21.01batch/s]
# Epoch [6/10], Train Loss: 0.9479, Train Acc: 65.64%, Val Loss: 0.9665, Val Acc: 65.24%
# Epoch 7/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:16<00:00, 20.88batch/s]
# Epoch [7/10], Train Loss: 0.8442, Train Acc: 69.47%, Val Loss: 0.9035, Val Acc: 68.04%
# Epoch 8/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:16<00:00, 21.01batch/s]
# Epoch [8/10], Train Loss: 0.7585, Train Acc: 72.79%, Val Loss: 0.8153, Val Acc: 70.84%
# Epoch 9/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:16<00:00, 21.03batch/s]
# Epoch [9/10], Train Loss: 0.6726, Train Acc: 75.86%, Val Loss: 0.8278, Val Acc: 71.18%
# Epoch 10/10: 100%|████████████████████████████████████████████████████████████████| 352/352 [00:16<00:00, 21.00batch/s]
# Epoch [10/10], Train Loss: 0.5937, Train Acc: 78.95%, Val Loss: 0.8377, Val Acc: 70.48%
# Testing: 100%|██████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 46.69batch/s]
# Test Accuracy on CIFAR-10 test set: 69.58%
# Training model with sharing option: deep
# Total parameters: 9261520
# Unique parameters: 116688
# Shared parameters: 9144832
# Epoch 1/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:20<00:00, 17.46batch/s]
# Epoch [1/10], Train Loss: 1.8487, Train Acc: 28.72%, Val Loss: 1.6652, Val Acc: 36.14%
# Epoch 2/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:20<00:00, 17.58batch/s]
# Epoch [2/10], Train Loss: 1.4833, Train Acc: 43.68%, Val Loss: 1.4556, Val Acc: 46.98%
# Epoch 3/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.63batch/s]
# Epoch [3/10], Train Loss: 1.2763, Train Acc: 52.57%, Val Loss: 1.2243, Val Acc: 54.60%
# Epoch 4/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.66batch/s]
# Epoch [4/10], Train Loss: 1.1219, Train Acc: 58.88%, Val Loss: 1.1509, Val Acc: 58.56%
# Epoch 5/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.68batch/s]
# Epoch [5/10], Train Loss: 1.0133, Train Acc: 63.19%, Val Loss: 1.0326, Val Acc: 62.46%
# Epoch 6/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.68batch/s]
# Epoch [6/10], Train Loss: 0.9032, Train Acc: 66.93%, Val Loss: 0.9263, Val Acc: 65.96%
# Epoch 7/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.67batch/s]
# Epoch [7/10], Train Loss: 0.8118, Train Acc: 70.51%, Val Loss: 0.9223, Val Acc: 65.62%
# Epoch 8/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.68batch/s]
# Epoch [8/10], Train Loss: 0.7236, Train Acc: 74.17%, Val Loss: 0.8386, Val Acc: 69.32%
# Epoch 9/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.69batch/s]
# Epoch [9/10], Train Loss: 0.6373, Train Acc: 77.41%, Val Loss: 0.7899, Val Acc: 70.76%
# Epoch 10/10: 100%|████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 17.66batch/s]
# Epoch [10/10], Train Loss: 0.5461, Train Acc: 80.46%, Val Loss: 0.7701, Val Acc: 71.76%
# Testing: 100%|██████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 42.29batch/s]
# Test Accuracy on CIFAR-10 test set: 72.04%
# Training model with sharing option: all
# Total parameters: 9266650
# Unique parameters: 41040
# Shared parameters: 9225610
# Epoch 1/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 50.14batch/s]
# Epoch [1/10], Train Loss: 1.8186, Train Acc: 31.51%, Val Loss: 1.5815, Val Acc: 41.12%
# Epoch 2/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:06<00:00, 51.35batch/s]
# Epoch [2/10], Train Loss: 1.4226, Train Acc: 47.07%, Val Loss: 1.3354, Val Acc: 51.88%
# Epoch 3/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.80batch/s]
# Epoch [3/10], Train Loss: 1.2329, Train Acc: 54.76%, Val Loss: 1.1998, Val Acc: 56.54%
# Epoch 4/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.81batch/s]
# Epoch [4/10], Train Loss: 1.0871, Train Acc: 60.38%, Val Loss: 1.0744, Val Acc: 60.76%
# Epoch 5/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.91batch/s]
# Epoch [5/10], Train Loss: 0.9854, Train Acc: 64.28%, Val Loss: 0.9902, Val Acc: 63.78%
# Epoch 6/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 50.06batch/s]
# Epoch [6/10], Train Loss: 0.8858, Train Acc: 68.22%, Val Loss: 0.9291, Val Acc: 66.82%
# Epoch 7/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.93batch/s]
# Epoch [7/10], Train Loss: 0.7924, Train Acc: 71.58%, Val Loss: 0.8563, Val Acc: 69.44%
# Epoch 8/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.69batch/s]
# Epoch [8/10], Train Loss: 0.6918, Train Acc: 75.58%, Val Loss: 0.8274, Val Acc: 70.04%
# Epoch 9/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.63batch/s]
# Epoch [9/10], Train Loss: 0.6027, Train Acc: 78.60%, Val Loss: 0.8204, Val Acc: 71.80%
# Epoch 10/10: 100%|████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.84batch/s]
# Epoch [10/10], Train Loss: 0.5191, Train Acc: 81.69%, Val Loss: 0.7859, Val Acc: 72.44%
# Testing: 100%|██████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 72.17batch/s]
# Test Accuracy on CIFAR-10 test set: 72.46%
# Test Accuracy for sharing option no_sharing: 72.08%
# Test Accuracy for sharing option early: 69.58%
# Test Accuracy for sharing option deep: 72.04%
# Test Accuracy for sharing option all: 72.46%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm  # For progress bars

# Set random seed for reproducibility
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

# Hyperparameters (You can adjust these)
num_epochs = 10           # Number of training epochs
batch_size = 128         # Batch size for training and validation
learning_rate = 0.0001    # Learning rate for optimizer
weight_decay = 1e-4      # Weight decay (L2 regularization)
validation_split = 0.1   # Fraction of training data to use for validation
num_heads = 8            # Number of ensemble members (heads)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Data preprocessing and loading
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],  # CIFAR-10 mean
        std=[0.2023, 0.1994, 0.2010]    # CIFAR-10 std
    ),
])

# Load the full training dataset
full_train_dataset = datasets.CIFAR10(root='./data', train=True,
                                      download=True, transform=transform)

# Split into training and validation datasets
train_size = int((1 - validation_split) * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(full_train_dataset, [train_size, val_size])

# Test dataset
test_dataset = datasets.CIFAR10(root='./data', train=False,
                                download=True, transform=transform)

# Data loaders
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                         batch_size=batch_size,
                                         shuffle=False)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)

# VGG11 with Combined Parameter Sharing
class VGG11CombinedSharing(nn.Module):
    def __init__(self, num_classes=10, num_heads=4,
                 intra_share='none', inter_share='no_sharing'):
        super(VGG11CombinedSharing, self).__init__()
        self.num_heads = num_heads
        self.intra_share = intra_share
        self.inter_share = inter_share

        # Shared layers across ensemble members
        self.shared_layers_inter = nn.Sequential()

        # Shared convolutional layers within ensemble members
        self.shared_conv_64 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.shared_conv_256 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.shared_conv_512 = nn.Conv2d(512, 512, kernel_size=3, padding=1)

        self.heads = nn.ModuleList()

        # Define the layers of VGG11
        layers = [
            # Conv1
            ('conv1_1', nn.Conv2d(3, 64, kernel_size=3, padding=1)),
            ('relu1_1', nn.ReLU(inplace=True)),
            ('conv1_2', nn.Conv2d(64, 64, kernel_size=3, padding=1)),
            ('relu1_2', nn.ReLU(inplace=True)),
            ('pool1', nn.MaxPool2d(kernel_size=2, stride=2)),

            # Conv2
            ('conv2_1', nn.Conv2d(64, 128, kernel_size=3, padding=1)),
            ('relu2_1', nn.ReLU(inplace=True)),
            ('pool2', nn.MaxPool2d(kernel_size=2, stride=2)),

            # Conv3
            ('conv3_1', nn.Conv2d(128, 256, kernel_size=3, padding=1)),
            ('relu3_1', nn.ReLU(inplace=True)),

            # Conv4
            ('conv4_1', nn.Conv2d(256, 256, kernel_size=3, padding=1)),
            ('relu4_1', nn.ReLU(inplace=True)),
            ('pool3', nn.MaxPool2d(kernel_size=2, stride=2)),

            # Conv5
            ('conv5_1', nn.Conv2d(256, 512, kernel_size=3, padding=1)),
            ('relu5_1', nn.ReLU(inplace=True)),

            # Conv6
            ('conv6_1', nn.Conv2d(512, 512, kernel_size=3, padding=1)),
            ('relu6_1', nn.ReLU(inplace=True)),
            ('pool4', nn.MaxPool2d(kernel_size=2, stride=2)),

            # Conv7
            ('conv7_1', nn.Conv2d(512, 512, kernel_size=3, padding=1)),
            ('relu7_1', nn.ReLU(inplace=True)),

            # Conv8
            ('conv8_1', nn.Conv2d(512, 512, kernel_size=3, padding=1)),
            ('relu8_1', nn.ReLU(inplace=True)),
            ('pool5', nn.MaxPool2d(kernel_size=2, stride=2)),
        ]

        # Determine which layers to share across ensemble members (inter-model sharing)
        if self.inter_share == 'no_sharing':
            inter_shared_indices = []
        elif self.inter_share == 'early':
            inter_shared_indices = list(range(5))  # Up to 'pool1'
        elif self.inter_share == 'deep':
            inter_shared_indices = list(range(5, len(layers)))  # From 'conv2_1' onwards
        elif self.inter_share == 'all':
            inter_shared_indices = list(range(len(layers)))  # All layers
        else:
            raise ValueError("Invalid inter_share option.")

        # Build shared layers across ensemble members
        for idx in inter_shared_indices:
            name, layer = layers[idx]
            self.shared_layers_inter.add_module(name, layer)

        # Build per-head layers
        for _ in range(num_heads):
            head_layers = nn.Sequential()
            for idx, (name, layer) in enumerate(layers):
                if idx not in inter_shared_indices:
                    # Implement intra-model sharing within each head
                    if self.intra_share in ['all', 'early'] and name.startswith('conv1'):
                        # Share conv1_2 layer within the head
                        if name == 'conv1_2':
                            head_layers.add_module(name, self.shared_conv_64)
                        else:
                            head_layers.add_module(name, layer)
                    elif self.intra_share in ['all', 'deep'] and name in ['conv4_1', 'conv6_1', 'conv7_1', 'conv8_1']:
                        # Share conv layers in deep part
                        if name.startswith('conv4'):
                            head_layers.add_module(name, self.shared_conv_256)
                        else:
                            head_layers.add_module(name, self.shared_conv_512)
                    else:
                        head_layers.add_module(name, layer)
            # Add classifier
            head_layers.add_module('flatten', nn.Flatten())
            head_layers.add_module('classifier', nn.Linear(512, num_classes))
            self.heads.append(head_layers)

        # If all layers are shared across ensemble members, add classifier to shared layers
        if self.inter_share == 'all':
            self.shared_layers_inter.add_module('flatten', nn.Flatten())
            self.shared_layers_inter.add_module('classifier', nn.Linear(512, num_classes))

    def forward(self, x):
        outputs = []
        if self.inter_share == 'deep':
            # For deep inter-model sharing, apply per-head layers first
            per_head_outputs = []
            for head in self.heads:
                # Apply per-head layers up to the split point
                out = head[:5](x.clone())  # Up to 'pool1'
                per_head_outputs.append(out)
            # Apply shared layers
            shared_outs = []
            for out in per_head_outputs:
                shared_out = self.shared_layers_inter(out)
                shared_outs.append(shared_out)
            # Apply per-head classifier layers
            for idx, out in enumerate(shared_outs):
                # The classifier is the last two layers in the per-head layers
                classifier = self.heads[idx][-2:]  # 'flatten' and 'classifier'
                out = classifier(out)
                outputs.append(out)
        else:
            if len(self.shared_layers_inter) > 0:
                x = self.shared_layers_inter(x)
            for head in self.heads:
                if self.inter_share == 'all':
                    out = x
                else:
                    out = head(x.clone())
                outputs.append(out)
        outputs = torch.stack(outputs)  # Shape: [num_heads, batch_size, num_classes]
        x = outputs.mean(dim=0)  # Average over ensemble members
        return x

# Function to count parameters considering both intra-model and inter-model sharing
def count_parameters_combined(model):
    total_params = sum(p.numel() for p in model.parameters())
    shared_param_ids = set()

    # Shared parameters across ensemble members (inter-model)
    if len(model.shared_layers_inter) > 0:
        shared_param_ids.update([id(p) for p in model.shared_layers_inter.parameters()])

    # Shared parameters within ensemble members (intra-model)
    if model.intra_share in ['all', 'early']:
        shared_param_ids.update([id(p) for p in model.shared_conv_64.parameters()])
    if model.intra_share in ['all', 'deep']:
        shared_param_ids.update([id(p) for p in model.shared_conv_256.parameters()])
        shared_param_ids.update([id(p) for p in model.shared_conv_512.parameters()])

    # Unique parameters
    unique_params = set()
    for param in model.parameters():
        if id(param) not in shared_param_ids:
            unique_params.add(id(param))

    num_shared_params = sum(p.numel() for p in model.parameters() if id(p) in shared_param_ids)
    num_unique_params = sum(p.numel() for p in model.parameters() if id(p) in unique_params)

    return num_unique_params, num_shared_params

# Training function with validation and progress bars
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        # Training loop with progress bar
        with tqdm(total=len(train_loader), desc=f'Epoch {epoch+1}/{num_epochs}', unit='batch') as pbar:
            for images, labels in train_loader:
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass
                outputs = model(images)
                loss = criterion(outputs, labels)

                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                running_loss += loss.item()

                # Calculate accuracy
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                pbar.update(1)

        epoch_loss = running_loss / len(train_loader)
        epoch_accuracy = 100 * correct / total
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_accuracy)

        # Validation loop
        model.eval()
        val_running_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                val_running_loss += loss.item()

                # Calculate accuracy
                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        val_loss = val_running_loss / len(val_loader)
        val_accuracy = 100 * val_correct / val_total
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)

        print(f'Epoch [{epoch+1}/{num_epochs}], '
              f'Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_accuracy:.2f}%, '
              f'Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%')

    return train_losses, val_losses, train_accuracies, val_accuracies

# Evaluation function on test set
def evaluate_model(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in tqdm(test_loader, desc='Testing', unit='batch'):
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    test_accuracy = 100 * correct / total
    return test_accuracy

# Plotting function with training and validation metrics
def plot_results(train_losses_list, val_losses_list, train_acc_list, val_acc_list, labels):
    num_models = len(train_losses_list)
    fig, axs = plt.subplots(2, num_models, figsize=(6 * num_models, 10))

    if num_models == 1:
        axs = [axs]

    for i in range(num_models):
        # Loss plot
        axs[0, i].plot(train_losses_list[i], label='Train Loss')
        axs[0, i].plot(val_losses_list[i], label='Val Loss')
        axs[0, i].set_xlabel('Epoch')
        axs[0, i].set_ylabel('Loss')
        axs[0, i].set_title(f'{labels[i]} Loss')
        axs[0, i].legend()

        # Accuracy plot
        axs[1, i].plot(train_acc_list[i], label='Train Acc')
        axs[1, i].plot(val_acc_list[i], label='Val Acc')
        axs[1, i].set_xlabel('Epoch')
        axs[1, i].set_ylabel('Accuracy (%)')
        axs[1, i].set_title(f'{labels[i]} Accuracy')
        axs[1, i].legend()

    plt.tight_layout()
    plt.show()

# Parameter distribution plotting function
@torch.no_grad()
def plot_parameter_distribution(model, model_label="Model"):
    params = []
    tags = []
    for name, param in model.named_parameters():
        params.append(param.cpu().flatten())
        tags += [name] * param.numel()
    params = torch.cat(params).numpy()
    tags = np.array(tags)
    df = pd.DataFrame({'Parameter Value': params, 'Parameter Name': tags})

    plt.figure(figsize=(8, 6))
    sns.kdeplot(data=df, x='Parameter Value', fill=True)
    plt.title(f'Parameter Distribution of {model_label}')
    plt.xlabel('Parameter Value')
    plt.ylabel('Density')
    plt.show()

# Main function to train and evaluate models with different sharing options
def main():
    # Define sharing options
    intra_sharing_options = ['none', 'early', 'deep', 'all']
    inter_sharing_options = ['no_sharing', 'early', 'deep', 'all']

    # You can customize the combinations you want to test
    sharing_combinations = [
        ('none', 'no_sharing'),
        ('early', 'early'),
        ('deep', 'deep'),
        ('all', 'all'),
    ]

    train_losses_list = []
    val_losses_list = []
    train_acc_list = []
    val_acc_list = []
    test_accuracies_list = []
    labels = []

    for intra_share, inter_share in sharing_combinations:
        label = f'Intra: {intra_share}, Inter: {inter_share}'
        print(f"\nTraining model with sharing options: {label}")
        model = VGG11CombinedSharing(num_heads=num_heads, intra_share=intra_share, inter_share=inter_share).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

        # Count parameters
        num_unique_params, num_shared_params = count_parameters_combined(model)
        total_params = num_unique_params + num_shared_params
        print(f"Total parameters: {total_params}")
        print(f"Unique parameters: {num_unique_params}")
        print(f"Shared parameters: {num_shared_params}")

        train_losses, val_losses, train_accuracies, val_accuracies = train_model(
            model, train_loader, val_loader, criterion, optimizer, num_epochs)
        test_accuracy = evaluate_model(model, test_loader)
        print(f'Test Accuracy on CIFAR-10 test set: {test_accuracy:.2f}%')

        train_losses_list.append(train_losses)
        val_losses_list.append(val_losses)
        train_acc_list.append(train_accuracies)
        val_acc_list.append(val_accuracies)
        test_accuracies_list.append(test_accuracy)
        labels.append(label)

        # Plot parameter distribution
        plot_parameter_distribution(model, model_label=label)

    # Plot training results
    plot_results(train_losses_list, val_losses_list, train_acc_list, val_acc_list, labels)

    # Print test accuracies
    for i, label in enumerate(labels):
        print(f'Test Accuracy for sharing options {label}: {test_accuracies_list[i]:.2f}%')

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Files already downloaded and verified
# Files already downloaded and verified
#
# Training model with sharing options: Intra: none, Inter: no_sharing
# Total parameters: 12285264
# Unique parameters: 12285264
# Shared parameters: 0
# Epoch 1/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:24<00:00, 14.64batch/s]
# Epoch [1/10], Train Loss: 1.9175, Train Acc: 26.49%, Val Loss: 1.6936, Val Acc: 33.84%
# Epoch 2/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 14.83batch/s]
# Epoch [2/10], Train Loss: 1.5544, Train Acc: 41.02%, Val Loss: 1.4498, Val Acc: 45.52%
# Epoch 3/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 14.67batch/s]
# Epoch [3/10], Train Loss: 1.3860, Train Acc: 48.22%, Val Loss: 1.2901, Val Acc: 51.92%
# Epoch 4/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 14.86batch/s]
# Epoch [4/10], Train Loss: 1.2267, Train Acc: 54.90%, Val Loss: 1.1390, Val Acc: 57.22%
# Epoch 5/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 14.92batch/s]
# Epoch [5/10], Train Loss: 1.0916, Train Acc: 60.13%, Val Loss: 1.1029, Val Acc: 59.08%
# Epoch 6/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 15.11batch/s]
# Epoch [6/10], Train Loss: 0.9878, Train Acc: 64.04%, Val Loss: 0.9723, Val Acc: 64.42%
# Epoch 7/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 15.07batch/s]
# Epoch [7/10], Train Loss: 0.8986, Train Acc: 67.51%, Val Loss: 0.9110, Val Acc: 67.24%
# Epoch 8/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 14.90batch/s]
# Epoch [8/10], Train Loss: 0.8169, Train Acc: 70.42%, Val Loss: 0.8245, Val Acc: 69.98%
# Epoch 9/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 14.85batch/s]
# Epoch [9/10], Train Loss: 0.7343, Train Acc: 73.86%, Val Loss: 0.7949, Val Acc: 71.54%
# Epoch 10/10: 100%|████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 14.85batch/s]
# Epoch [10/10], Train Loss: 0.6654, Train Acc: 76.20%, Val Loss: 0.7556, Val Acc: 72.76%
# Testing: 100%|██████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 37.89batch/s]
# Test Accuracy on CIFAR-10 test set: 72.84%
# Training model with sharing options: Intra: early, Inter: early
# Total parameters: 12285264
# Unique parameters: 12209616
# Shared parameters: 75648
# Epoch 1/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 18.00batch/s]
# Epoch [1/10], Train Loss: 1.8944, Train Acc: 26.42%, Val Loss: 1.6668, Val Acc: 36.26%
# Epoch 2/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:18<00:00, 18.71batch/s]
# Epoch [2/10], Train Loss: 1.4995, Train Acc: 43.03%, Val Loss: 1.3960, Val Acc: 47.22%
# Epoch 3/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:18<00:00, 18.90batch/s]
# Epoch [3/10], Train Loss: 1.2903, Train Acc: 52.09%, Val Loss: 1.1846, Val Acc: 57.00%
# Epoch 4/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:18<00:00, 18.72batch/s]
# Epoch [4/10], Train Loss: 1.1294, Train Acc: 58.67%, Val Loss: 1.0706, Val Acc: 60.98%
# Epoch 5/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:18<00:00, 18.67batch/s]
# Epoch [5/10], Train Loss: 0.9944, Train Acc: 63.91%, Val Loss: 0.9781, Val Acc: 64.26%
# Epoch 6/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:18<00:00, 18.62batch/s]
# Epoch [6/10], Train Loss: 0.8929, Train Acc: 67.54%, Val Loss: 0.9397, Val Acc: 66.16%
# Epoch 7/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 18.22batch/s]
# Epoch [7/10], Train Loss: 0.8052, Train Acc: 70.80%, Val Loss: 0.8872, Val Acc: 67.98%
# Epoch 8/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 18.40batch/s]
# Epoch [8/10], Train Loss: 0.7193, Train Acc: 74.32%, Val Loss: 0.7918, Val Acc: 71.18%
# Epoch 9/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 18.40batch/s]
# Epoch [9/10], Train Loss: 0.6508, Train Acc: 76.70%, Val Loss: 0.7654, Val Acc: 72.60%
# Epoch 10/10: 100%|████████████████████████████████████████████████████████████████| 352/352 [00:19<00:00, 18.39batch/s]
# Epoch [10/10], Train Loss: 0.5746, Train Acc: 79.34%, Val Loss: 0.7284, Val Acc: 74.24%
# Testing: 100%|██████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 42.96batch/s]
# Test Accuracy on CIFAR-10 test set: 73.43%
# Training model with sharing options: Intra: deep, Inter: deep
# Total parameters: 12285264
# Unique parameters: 116688
# Shared parameters: 12168576
# Epoch 1/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:24<00:00, 14.44batch/s]
# Epoch [1/10], Train Loss: 1.8908, Train Acc: 26.98%, Val Loss: 1.6334, Val Acc: 37.76%
# Epoch 2/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:24<00:00, 14.53batch/s]
# Epoch [2/10], Train Loss: 1.4985, Train Acc: 42.55%, Val Loss: 1.4026, Val Acc: 47.22%
# Epoch 3/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:24<00:00, 14.51batch/s]
# Epoch [3/10], Train Loss: 1.3273, Train Acc: 50.58%, Val Loss: 1.2401, Val Acc: 54.62%
# Epoch 4/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:24<00:00, 14.50batch/s]
# Epoch [4/10], Train Loss: 1.1748, Train Acc: 56.86%, Val Loss: 1.1027, Val Acc: 59.66%
# Epoch 5/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:24<00:00, 14.48batch/s]
# Epoch [5/10], Train Loss: 1.0455, Train Acc: 61.80%, Val Loss: 0.9746, Val Acc: 64.50%
# Epoch 6/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 14.88batch/s]
# Epoch [6/10], Train Loss: 0.9381, Train Acc: 65.72%, Val Loss: 0.9741, Val Acc: 64.24%
# Epoch 7/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 14.99batch/s]
# Epoch [7/10], Train Loss: 0.8564, Train Acc: 68.86%, Val Loss: 0.8923, Val Acc: 66.94%
# Epoch 8/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 14.98batch/s]
# Epoch [8/10], Train Loss: 0.7696, Train Acc: 72.34%, Val Loss: 0.8113, Val Acc: 70.18%
# Epoch 9/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 14.99batch/s]
# Epoch [9/10], Train Loss: 0.6975, Train Acc: 74.98%, Val Loss: 0.7525, Val Acc: 72.88%
# Epoch 10/10: 100%|████████████████████████████████████████████████████████████████| 352/352 [00:23<00:00, 15.01batch/s]
# Epoch [10/10], Train Loss: 0.6178, Train Acc: 77.85%, Val Loss: 0.7284, Val Acc: 73.76%
# Testing: 100%|██████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 38.63batch/s]
# Test Accuracy on CIFAR-10 test set: 74.24%
# Training model with sharing options: Intra: all, Inter: all
# Total parameters: 12290394
# Unique parameters: 41040
# Shared parameters: 12249354
# Epoch 1/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 47.93batch/s]
# Epoch [1/10], Train Loss: 1.8343, Train Acc: 29.61%, Val Loss: 1.5822, Val Acc: 39.88%
# Epoch 2/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 48.68batch/s]
# Epoch [2/10], Train Loss: 1.4537, Train Acc: 44.96%, Val Loss: 1.4044, Val Acc: 47.76%
# Epoch 3/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 48.94batch/s]
# Epoch [3/10], Train Loss: 1.2603, Train Acc: 53.30%, Val Loss: 1.1825, Val Acc: 56.60%
# Epoch 4/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.04batch/s]
# Epoch [4/10], Train Loss: 1.1169, Train Acc: 59.17%, Val Loss: 1.0476, Val Acc: 61.96%
# Epoch 5/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.07batch/s]
# Epoch [5/10], Train Loss: 0.9971, Train Acc: 63.76%, Val Loss: 0.9876, Val Acc: 63.32%
# Epoch 6/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.15batch/s]
# Epoch [6/10], Train Loss: 0.8993, Train Acc: 67.43%, Val Loss: 0.9260, Val Acc: 66.14%
# Epoch 7/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.06batch/s]
# Epoch [7/10], Train Loss: 0.8078, Train Acc: 71.00%, Val Loss: 0.8867, Val Acc: 67.58%
# Epoch 8/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.15batch/s]
# Epoch [8/10], Train Loss: 0.7213, Train Acc: 74.13%, Val Loss: 0.7910, Val Acc: 71.00%
# Epoch 9/10: 100%|█████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.23batch/s]
# Epoch [9/10], Train Loss: 0.6412, Train Acc: 77.00%, Val Loss: 0.8201, Val Acc: 70.26%
# Epoch 10/10: 100%|████████████████████████████████████████████████████████████████| 352/352 [00:07<00:00, 49.12batch/s]
# Epoch [10/10], Train Loss: 0.5548, Train Acc: 80.32%, Val Loss: 0.7184, Val Acc: 74.40%
# Testing: 100%|██████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 74.26batch/s]
# Test Accuracy on CIFAR-10 test set: 73.95%
# Test Accuracy for sharing options Intra: none, Inter: no_sharing: 72.84%
# Test Accuracy for sharing options Intra: early, Inter: early: 73.43%
# Test Accuracy for sharing options Intra: deep, Inter: deep: 74.24%
# Test Accuracy for sharing options Intra: all, Inter: all: 73.95%
